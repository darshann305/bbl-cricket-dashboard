# %%
import pandas as pd
import os
import glob

folder_path = r"C:\Users\HP\OneDrive\Desktop\bbl-cricket-dashboard\data\raw\bbl_male_csv2"

# Get ALL csv files first
all_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Then separate them cleanly — this works reliably on Windows
ball_files = [f for f in all_files if not f.endswith("_info.csv")]
info_files = [f for f in all_files if f.endswith("_info.csv")]

print(f"Ball files found: {len(ball_files)}")
print(f"Info files found: {len(info_files)}")
# Out:
# Ball files found: 663
# Info files found: 662

# %%
# Combine ball-by-ball files
ball_dfs = []
for file in ball_files:
    match_id = os.path.basename(file).replace(".csv", "")
    temp_df = pd.read_csv(file, on_bad_lines="skip")  # skips any corrupt rows
    temp_df["match_id"] = match_id
    ball_dfs.append(temp_df)

balls = pd.concat(ball_dfs, ignore_index=True)
print(f"✅ Ball-by-ball data: {balls.shape}")
print(balls.head())
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8216\520627063.py:5: DtypeWarning: Columns (19,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_df = pd.read_csv(file, on_bad_lines="skip")  # skips any corrupt rows
# ✅ Ball-by-ball data: (306500, 27)
#   match_id   season  start_date                      venue  innings  ball  \
# 0  1023581  2016/17  2016-12-20  Sydney Showground Stadium        1   0.1
# 1  1023581  2016/17  2016-12-20  Sydney Showground Stadium        1   0.2
# 2  1023581  2016/17  2016-12-20  Sydney Showground Stadium        1   0.3
# 3  1023581  2016/17  2016-12-20  Sydney Showground Stadium        1   0.4
# 4  1023581  2016/17  2016-12-20  Sydney Showground Stadium        1   0.5
#
#    actual_delivery    batting_team   bowling_team       striker  ... legbyes  \
# 0              0.1  Sydney Thunder  Sydney Sixers  KR Patterson  ...     NaN
# 1              0.2  Sydney Thunder  Sydney Sixers  KR Patterson  ...     NaN
# 2              0.3  Sydney Thunder  Sydney Sixers  KR Patterson  ...     NaN
# 3              0.4  Sydney Thunder  Sydney Sixers  KR Patterson  ...     NaN
# 4              0.5  Sydney Thunder  Sydney Sixers  KR Patterson  ...     NaN
#
#   penalty  non_boundary  wicket_type  player_dismissed  other_wicket_type  \
# 0     NaN           NaN          NaN               NaN                NaN
# 1     NaN           NaN          NaN               NaN                NaN
# 2     NaN           NaN          NaN               NaN                NaN
# 3     NaN           NaN          NaN               NaN                NaN
# 4     NaN           NaN          NaN               NaN                NaN
#
#    other_player_dismissed  fielder_1  fielder_2 fielder_3
# 0                     NaN        NaN        NaN       NaN
# 1                     NaN        NaN        NaN       NaN
# 2                     NaN        NaN        NaN       NaN
# 3                     NaN        NaN        NaN       NaN
# 4                     NaN        NaN        NaN       NaN
#
# [5 rows x 27 columns]

# %%
# Combine info files
info_dfs = []
for file in info_files:
    match_id = os.path.basename(file).replace("_info.csv", "")
    temp_df = pd.read_csv(file, on_bad_lines="skip")
    temp_df["match_id"] = match_id
    info_dfs.append(temp_df)

info = pd.concat(info_dfs, ignore_index=True)
print(f"✅ Info data: {info.shape}")
print(info.head())
# Out:
# ✅ Info data: (15661, 3)
#           version           2.3.0 match_id
# 0  balls_per_over               6  1023581
# 1            team  Sydney Thunder  1023581
# 2            team   Sydney Sixers  1023581
# 3       team_type            club  1023581
# 4          gender            male  1023581

# %%
info.columns = ["info", "value", "match_id"]

print("✅ Columns renamed")
print(info.head(15))

print("\n📋 All info categories:")
print(info["info"].value_counts())
# Out:
# ✅ Columns renamed
#               info                      value match_id
# 0   balls_per_over                          6  1023581
# 1             team             Sydney Thunder  1023581
# 2             team              Sydney Sixers  1023581
# 3        team_type                       club  1023581
# 4           gender                       male  1023581
# 5           season                    2016/17  1023581
# 6             date                 2016/12/20  1023581
# 7            event            Big Bash League  1023581
# 8         match_id                    1023581  1023581
# 9       match_type                        T20  1023581
# 10           overs                         20  1023581
# 11    match_number                          1  1023581
# 12           venue  Sydney Showground Stadium  1023581
# 13            city                        NaN  1023581
# 14     toss_winner              Sydney Sixers  1023581
#
# 📋 All info categories:
# info
# umpire             1324
# team               1324
# balls_per_over      662
# overs               662
# match_referee       662
# toss_decision       662
# city                662
# venue               662
# toss_winner         662
# match_type          662
# gender              662
# match_id            662
# event               662
# date                662
# season              662
# team_type           662
# tv_umpire           654
# player_of_match     651
# winner              647
# reserve_umpire      592
# match_number        495
# winner_wickets      336
# winner_runs         311
# method               32
# outcome              15
# super_over            8
# eliminator            4
# Name: count, dtype: int64

# %%
import os

os.makedirs(r"C:\Users\HP\OneDrive\Desktop\bbl-cricket-dashboard\data\processed", exist_ok=True)

balls.to_parquet(r"C:\Users\HP\OneDrive\Desktop\bbl-cricket-dashboard\data\processed\balls.parquet", index=False)
info.to_parquet(r"C:\Users\HP\OneDrive\Desktop\bbl-cricket-dashboard\data\processed\info.parquet", index=False)

print("✅ Both files saved to processed folder!")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 5
#       1 import os
#       3 os.makedirs(r"C:\Users\HP\OneDrive\Desktop\bbl-cricket-dashboard\data\processed", exist_ok=True)
# ----> 5 balls.to_parquet(r"C:\Users\HP\OneDrive\Desktop\bbl-cricket-dashboard\data\processed", index=False)
#       6 info.to_parquet(r"C:\Users\HP\OneDrive\Desktop\bbl-cricket-dashboard\data\processed", index=False)
#       8 print("✅ Both files saved to processed folder!")
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3124, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3043 """
#    3044 Write a DataFrame to the binary parquet format.
#    3045
#    (...)   3120 >>> content = f.read()
#    3121 """
#    3122 from pandas.io.parquet import to_parquet
# -> 3124 return to_parquet(
#    3125     self,
#    3126     path,
#    3127     engine,
#    3128     compression=compression,
#    3129     index=index,
#    3130     partition_cols=partition_cols,
#    3131     storage_options=storage_options,
#    3132     **kwargs,
#    3133 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parquet.py:482, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     478 impl = get_engine(engine)
#     480 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 482 impl.write(
#     483     df,
#     484     path_or_buf,
#     485     compression=compression,
#     486     index=index,
#     487     partition_cols=partition_cols,
#     488     storage_options=storage_options,
#     489     filesystem=filesystem,
#     490     **kwargs,
#     491 )
#     493 if path is None:
#     494     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parquet.py:229, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     219         self.api.parquet.write_to_dataset(
#     220             table,
#     221             path_or_handle,
#    (...)    225             **kwargs,
#     226         )
#     227     else:
#     228         # write to single output file
# --> 229         self.api.parquet.write_table(
#     230             table,
#     231             path_or_handle,
#     232             compression=compression,
#     233             filesystem=filesystem,
#     234             **kwargs,
#     235         )
#     236 finally:
#     237     if handles is not None:
#
# File ~\anaconda3\Lib\site-packages\pyarrow\parquet\core.py:1957, in write_table(table, where, row_group_size, version, use_dictionary, compression, write_statistics, use_deprecated_int96_timestamps, coerce_timestamps, allow_truncated_timestamps, data_page_size, flavor, filesystem, compression_level, use_byte_stream_split, column_encoding, data_page_version, use_compliant_nested_type, encryption_properties, write_batch_size, dictionary_pagesize_limit, store_schema, write_page_index, write_page_checksum, sorting_columns, store_decimal_as_integer, **kwargs)
#    1955 use_int96 = use_deprecated_int96_timestamps
#    1956 try:
# -> 1957     with ParquetWriter(
#    1958             where, table.schema,
#    1959             filesystem=filesystem,
#    1960             version=version,
#    1961             flavor=flavor,
#    1962             use_dictionary=use_dictionary,
#    1963             write_statistics=write_statistics,
#    1964             coerce_timestamps=coerce_timestamps,
#    1965             data_page_size=data_page_size,
#    1966             allow_truncated_timestamps=allow_truncated_timestamps,
#    1967             compression=compression,
#    1968             use_deprecated_int96_timestamps=use_int96,
#    1969             compression_level=compression_level,
#    1970             use_byte_stream_split=use_byte_stream_split,
#    1971             column_encoding=column_encoding,
#    1972             data_page_version=data_page_version,
#    1973             use_compliant_nested_type=use_compliant_nested_type,
#    1974             encryption_properties=encryption_properties,
#    1975             write_batch_size=write_batch_size,
#    1976             dictionary_pagesize_limit=dictionary_pagesize_limit,
#    1977             store_schema=store_schema,
#    1978             write_page_index=write_page_index,
#    1979             write_page_checksum=write_page_checksum,
#    1980             sorting_columns=sorting_columns,
#    1981             store_decimal_as_integer=store_decimal_as_integer,
#    1982             **kwargs) as writer:
#    1983         writer.write_table(table, row_group_size=row_group_size)
#    1984 except Exception:
#
# File ~\anaconda3\Lib\site-packages\pyarrow\parquet\core.py:1064, in ParquetWriter.__init__(self, where, schema, filesystem, flavor, version, use_dictionary, compression, write_statistics, use_deprecated_int96_timestamps, compression_level, use_byte_stream_split, column_encoding, writer_engine_version, data_page_version, use_compliant_nested_type, encryption_properties, write_batch_size, dictionary_pagesize_limit, store_schema, write_page_index, write_page_checksum, sorting_columns, store_decimal_as_integer, **options)
#    1059 filesystem, path = _resolve_filesystem_and_path(where, filesystem)
#    1060 if filesystem is not None:
#    1061     # ARROW-10480: do not auto-detect compression.  While
#    1062     # a filename like foo.parquet.gz is nonconforming, it
#    1063     # shouldn't implicitly apply compression.
# -> 1064     sink = self.file_handle = filesystem.open_output_stream(
#    1065         path, compression=None)
#    1066 else:
#    1067     sink = where
#
# File ~\anaconda3\Lib\site-packages\pyarrow\_fs.pyx:912, in pyarrow._fs.FileSystem.open_output_stream()
#
# File ~\anaconda3\Lib\site-packages\pyarrow\error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~\anaconda3\Lib\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# PermissionError: [WinError 5] Failed to open local file 'C:/Users/HP/OneDrive/Desktop/bbl-cricket-dashboard/data/processed'. Detail: [Windows error 5] Access is denied.
